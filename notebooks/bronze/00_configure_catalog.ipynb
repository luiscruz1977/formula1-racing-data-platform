# %%
CATALOG = "formula1_racing"
BRONZE = "bronze"
SILVER = "silver"
GOLD = "gold"
RAW_PATH = f"/Volumes/{CATALOG}/{BRONZE}/raw_files"

# %%
# Create Bronze Schema
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1_racing.bronze")
# Create Silver Schema
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1_racing.silver")
# Create Gold Schema
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1_racing.gold")

# %%
# Create Volume
spark.sql("CREATE VOLUME IF NOT EXISTS formula1_racing.bronze.raw_files")
